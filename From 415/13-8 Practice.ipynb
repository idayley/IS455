# %%
import pandas as pd
df = pd.read_csv('http://www.ishelp.info/data/heart_attack.csv')
df.head()
# Out:
#    age  sex  cp trestbps chol fbs  ... exang oldpeak slope  ca thal num
# 0   28    1   2      130  132   0  ...     0     0.0     ?   ?    ?   0
# 1   29    1   2      120  243   0  ...     0     0.0     ?   ?    ?   0
# 2   29    1   2      140    ?   0  ...     0     0.0     ?   ?    ?   0
# 3   30    0   1      170  237   0  ...     0     0.0     ?   ?    6   0
# 4   31    0   2      100  219   0  ...     0     0.0     ?   ?    ?   0
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (294, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
print(f'age: {df.age.nunique()}')
print(f'sex: {df.sex.nunique()}')
print(f'cp: {df.cp.nunique()}')
print(f'trestbps: {df.trestbps.nunique()}')
print(f'chol: {df.chol.nunique()}')
print(f'fbs: {df.fbs.nunique()}')
print(f'restecg: {df.restecg.nunique()}')
print(f'thalach: {df.thalach.nunique()}')
print(f'exang: {df.exang.nunique()}')
print(f'slope: {df.slope.nunique()}')
print(f'oldpeak: {df.oldpeak.nunique()}')
print(f'ca: {df.ca.nunique()}')
print(f'thal: {df.thal.nunique()}')
print(f'num: {df.num.nunique()}')
# Out:
# age: 38
# sex: 2
# cp: 4
# trestbps: 32
# chol: 154
# fbs: 3
# restecg: 4
# thalach: 72
# exang: 3
# slope: 4
# oldpeak: 10
# ca: 2
# thal: 4
# num: 2

# %%
print(f'age: {df.age.dtype}')
print(f'sex: {df.sex.dtype}')
print(f'cp: {df.cp.dtype}')
print(f'trestbps: {df.trestbps.dtype}')
print(f'chol: {df.chol.dtype}')
print(f'fbs: {df.fbs.dtype}')
print(f'restecg: {df.restecg.dtype}')
print(f'thalach: {df.thalach.dtype}')
print(f'exang: {df.exang.dtype}')
print(f'slope: {df.slope.dtype}')
print(f'oldpeak: {df.oldpeak.dtype}')
print(f'ca: {df.ca.dtype}')
print(f'thal: {df.thal.dtype}')
print(f'num: {df.num.dtype}')
# Out:
# age: int64
# sex: int64
# cp: int64
# trestbps: object
# chol: object
# fbs: object
# restecg: object
# thalach: object
# exang: object
# slope: object
# oldpeak: float64
# ca: object
# thal: object
# num: int64

# %%
df.describe()
# Out:
#               age         sex          cp     oldpeak         num
# count  294.000000  294.000000  294.000000  294.000000  294.000000
# mean    47.826531    0.724490    2.982993    0.586054    0.360544
# std      7.811812    0.447533    0.965117    0.908648    0.480977
# min     28.000000    0.000000    1.000000    0.000000    0.000000
# 25%     42.000000    0.000000    2.000000    0.000000    0.000000
# 50%     49.000000    1.000000    3.000000    0.000000    0.000000
# 75%     54.000000    1.000000    4.000000    1.000000    1.000000
# max     66.000000    1.000000    4.000000    5.000000    1.000000

# %%
#I copied and pasted this from his example so idk why it doesn't work
import numpy as np

print(df.charges.min())
print(df.charges.quantile(.25))
print(df.charges.quantile(.50))
print(df.charges.quantile(.75))
print(df.charges.max())

print(df.charges.mean())
print(df.charges.median())
print(df.charges.mode().values[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-98ce589052ec> in <module>()
#       1 import numpy as np
#       2
# ----> 3 print(df.charges.min())
#       4 print(df.charges.quantile(.25))
#       5 print(df.charges.quantile(.50))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'charges'
