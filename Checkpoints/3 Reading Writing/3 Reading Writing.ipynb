# %% [markdown]
# ### READ ME
#
# Use the code blocks below to answer each quiz question. Only print the output required for each question. Do not edit the comments at the top of each code cell. Otherwise, the auto-grader may misinterpret your results. See Question 0 as an an example of how to complete a task (leave it in your notebook; don't delete it):

# %%
# Question 0: Create a DataFrame with three rows and four columns. Name the 
# columns 'Col1', 'Col2', 'Col3', 'Col4'. Create an index for the DataFrame
# and give the rows the index values of 'Row1', 'Row2', 'Row3'. Place a value
# in each column equal to the {ColumnName/RowName}. e.g. Col1/Row1. Print
# the entire DataFrame.

import pandas as pd

df = pd.DataFrame(columns=['Col1', 'Col2', 'Col3', 'Col4'], index=['Row1', 'Row2', 'Row3'])

for col in df:
  for i, value in df[col].items():
    df.at[i, col] = f'{i}/{col}'

df

# %%
# Question 1: 

# Read each dataset into its own DataFrame; e.g. df_projects, df_resources, df_schools, etc.
# NOTE: donors.db contains a single table called "donors"
# print the columns found in each DataFrame in any order you want

import pandas as pd
import pyodbc
import sqlite3

#donors
conn = sqlite3.connect('donors.db')
df_donors = pd.read_sql(sql="SELECT * FROM donors", con=conn)
print('donors')
print(df_donors.columns)
print('___________________________________')

#donations
df_donations = pd.read_json('donations.json')
print('donations')
print(df_donations.columns)
print('___________________________________')

#projects
df_projects = pd.read_csv('projects.csv')
print('projects')
print(df_projects.columns)
print('___________________________________')

#resources
df_resources = pd.read_csv('resources.csv')
print('resources')
print(df_resources.columns)
print('___________________________________')

#schools
df_schools = pd.read_csv('schools.csv')
print('schools')
print(df_schools.columns)
print('___________________________________')

#teachers
df_teachers = pd.read_csv('teachers.csv')
print('teachers')
print(df_teachers.columns)
print('___________________________________')
# Out:
# donors
# Index(['Donor ID', 'Donor City', 'Donor State', 'Donor Is Teacher'], dtype='object')
# ___________________________________
# donations
# Index(['Project ID', 'Donation ID', 'Donor ID',
#        'Donation Included Optional Donation', 'Donation Amount',
#        'Donor Cart Sequence', 'Donation Received Date'],
#       dtype='object')
# ___________________________________
# projects
# Index(['Project ID', 'School ID', 'Teacher ID',
#        'Teacher Project Posted Sequence', 'Project Type', 'Project Title',
#        'Project Essay', 'Project Short Description', 'Project Need Statement',
#        'Project Subject Category Tree', 'Project Subject Subcategory Tree',
#        'Project Grade Level Category', 'Project Resource Category',
#        'Project Cost', 'Year', 'Month', 'Weekday', 'Project Current Status',
#        'Days to Funded', 'Days Live'],
#       dtype='object')
# ___________________________________
# resources
# Index(['Project ID', 'Resource Item Name', 'Resource Quantity',
#        'Resource Unit Price', 'Resource Vendor Name'],
#       dtype='object')
# ___________________________________
# schools
# Index(['School ID', 'School Name', 'School Metro Type',
#        'School Percentage Free Lunch', 'School State', 'School Zip',
#        'School City', 'School County', 'School District'],
#       dtype='object')
# ___________________________________
# teachers
# Index(['Teacher ID', 'Teacher Prefix', 'Teacher First Project Posted Date'], dtype='object')
# ___________________________________

# %%
# Question 2: 

# Merge the six DataFrames into a single DataFrame called df
# Infer the primary key/foreign key relationships based on connecting matching column ID names
# Print the complete column list of df
# Print the first five records

df = pd.merge(df_donors, df_donations, how='inner', on=['Donor ID'])
df = pd.merge(df, df_projects, how='inner', on=['Project ID'])
df = pd.merge(df, df_resources, how='inner', on=['Project ID'])
df = pd.merge(df, df_schools, how='inner', on=['School ID'])
df = pd.merge(df, df_teachers, how='inner', on=['Teacher ID'])

print(df.columns)

df.head(5)
# Out:
# Index(['Donor ID', 'Donor City', 'Donor State', 'Donor Is Teacher',
#        'Project ID', 'Donation ID', 'Donation Included Optional Donation',
#        'Donation Amount', 'Donor Cart Sequence', 'Donation Received Date',
#        'School ID', 'Teacher ID', 'Teacher Project Posted Sequence',
#        'Project Type', 'Project Title', 'Project Essay',
#        'Project Short Description', 'Project Need Statement',
#        'Project Subject Category Tree', 'Project Subject Subcategory Tree',
#        'Project Grade Level Category', 'Project Resource Category',
#        'Project Cost', 'Year', 'Month', 'Weekday', 'Project Current Status',
#        'Days to Funded', 'Days Live', 'Resource Item Name',
#        'Resource Quantity', 'Resource Unit Price', 'Resource Vendor Name',
#        'School Name', 'School Metro Type', 'School Percentage Free Lunch',
#        'School State', 'School Zip', 'School City', 'School County',
#        'School District', 'Teacher Prefix',
#        'Teacher First Project Posted Date'],
#       dtype='object')
#                            Donor ID    Donor City Donor State  \
# 0  09762b95beeebf373350f5c5d7cce352  Spanish Fork       other
# 1  0c47295a9944e27b83635049227da61e          None        Utah
# 2  d58e0de79e4530c2dca3816da98513b7      New York    New York
# 3  f91e212cb706479a8770a6af883413f3     Las Vegas      Nevada
# 4  a0a11cc31b74779c756f9c4c12c06519          None        Ohio
#
#   Donor Is Teacher                        Project ID  \
# 0               No  5a6d12aaa92eed3858fca54bd2f69f9c
# 1               No  5a6d12aaa92eed3858fca54bd2f69f9c
# 2               No  5a6d12aaa92eed3858fca54bd2f69f9c
# 3               No  5a6d12aaa92eed3858fca54bd2f69f9c
# 4               No  5a6d12aaa92eed3858fca54bd2f69f9c
#
#                         Donation ID Donation Included Optional Donation  \
# 0  54c4cdf9bf3dd81242a0985de75eaec7                                 Yes
# 1  42a14070b5162cf3bd5f997d5f473386                                 Yes
# 2  5f2688e1a5881b0fc743c4d10e2d5c6b                                  No
# 3  4f8c581492aa623328ece2058436a5b8                                 Yes
# 4  2188f030905528fe4781133fcf15ade7                                 Yes
#
#    Donation Amount  Donor Cart Sequence Donation Received Date  ...  \
# 0             15.0                    2    2013-02-11 13:22:50  ...
# 1             40.0                    1    2013-02-17 23:47:42  ...
# 2             15.0                    1    2013-02-17 18:50:07  ...
# 3             50.0                    1    2013-02-17 23:29:46  ...
# 4             10.0                    1    2013-02-11 13:34:32  ...
#
#               School Name School Metro Type  School Percentage Free Lunch  \
# 0  Eastmont Middle School          suburban                          31.0
# 1  Eastmont Middle School          suburban                          31.0
# 2  Eastmont Middle School          suburban                          31.0
# 3  Eastmont Middle School          suburban                          31.0
# 4  Eastmont Middle School          suburban                          31.0
#
#   School State School Zip School City School County          School District  \
# 0         Utah      84094       Sandy     Salt Lake  Canyons School District
# 1         Utah      84094       Sandy     Salt Lake  Canyons School District
# 2         Utah      84094       Sandy     Salt Lake  Canyons School District
# 3         Utah      84094       Sandy     Salt Lake  Canyons School District
# 4         Utah      84094       Sandy     Salt Lake  Canyons School District
#
#   Teacher Prefix Teacher First Project Posted Date
# 0           Mrs.                        2011-10-18
# 1           Mrs.                        2011-10-18
# 2           Mrs.                        2011-10-18
# 3           Mrs.                        2011-10-18
# 4           Mrs.                        2011-10-18
#
# [5 rows x 43 columns]

# %%
# Question 3:

# Print the number of rows in this new DataFrame df

# %%
# Question 4:

# Filter out all records that are not in Utah County. In other words, only Utah County records should remain in the DataFrame df
# Print the number of rows in this reduced DataFrame

# %%
# Question 5:

# Print the average donation value from this reduced dataset

# %%
# Question 6:

# Print the median donation value from this reduced dataset

# %%
# Question 7:

# Print the donation value skewness from this reduced dataset

# %%
# Question 8:

# Store df in a new sqlite db called donors_choose.db using the table name donors_choose
