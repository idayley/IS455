# %%
import pandas as pd

df = pd.read_csv('https://www.ishelp.info/data/tweets_aws.csv')
df
# Out:
#       Gender    Weekday  Hour  Day   Reach  RetweetCount  Klout  Sentiment  \
# 0       Male     Monday    23    2    4037             1     52        3.0
# 1    Unknown     Friday    12    4  524418            21     72        0.0
# 2    Unknown    Tuesday     9   31    1748             1     46        0.0
# 3    Unknown   Saturday     3   27    1179             1      0        0.0
# 4    Unknown   Saturday     3   27    1179             1      0        0.0
# ..       ...        ...   ...  ...     ...           ...    ...        ...
# 995  Unknown    Tuesday    12   15   12532            20     59        3.0
# 996     Male    Tuesday     6   31     822             1     45        0.0
# 997     Male  Wednesday     3   27     544             6     41        0.0
# 998  Unknown    Tuesday     8   19  582387             2     73        0.0
# 999     Male   Thursday    18   16      57             1     23        0.0
#
#                                                   text
# 0    Amazon Web Services is becoming a nice predict...
# 1    Announcing four new VPN features in our Sao Pa...
# 2    Are you an @awscloud user? Use #Zadara + #AWS ...
# 3    AWS CloudFormation Adds Support for Amazon VPC...
# 4    AWS CloudFormation Adds Support for Amazon VPC...
# ..                                                 ...
# 995  Friends dont let friends build datacenters. Ce...
# 996  "Check out Amazon Web Services Big Data Day co...
# 997  Slides and the demo project related to my #AWS...
# 998  Teradata SW leading #BI #DataWarehouse availab...
# 999  Amazon EC2 simplifies Spot usage experience wi...
#
# [1000 rows x 9 columns]

# %%
# !pip uninstall pandas
# !pip install pandas==1.1.5
# !pip install pyLDAvis
# !pip install pyLDAvis.gensim
# !pip install bokeh
# !pip install gensim
# !pip install spacy
# !pip install logging
# !pip install wordcloud
# !pip install nltk
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !pip install -U seaborn
# !pip install translators --upgrade
# !pip install --upgrade pip
# Out:
# ^C
# Collecting pandas==1.1.5
#   Downloading pandas-1.1.5-cp38-cp38-win_amd64.whl (9.0 MB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas==1.1.5) (2021.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas==1.1.5) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas==1.1.5) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.7.3->pandas==1.1.5) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.2
#     Uninstalling pandas-1.3.2:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Acer\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python38\\site-packages\\~andas\\_libs\\algos.cp38-win_amd64.pyd'
# Check the permissions.
#
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
#       Successfully uninstalled pandas-1.3.2
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting funcy
#   WARNING: The scripts cygdb.exe, cython.exe and cythonize.exe are installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
#   Downloading funcy-1.16-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: scikit-learn in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pyLDAvis) (1.0)
# Requirement already satisfied: setuptools in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: scipy in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pyLDAvis) (1.7.1)
# Collecting jinja2
#   Downloading Jinja2-3.0.2-py3-none-any.whl (133 kB)
# Collecting numexpr
#   Downloading numexpr-2.7.3-cp38-cp38-win_amd64.whl (93 kB)
# Collecting gensim
#   Downloading gensim-4.1.2-cp38-cp38-win_amd64.whl (24.0 MB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: sklearn in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pyLDAvis) (0.0)
# Collecting pandas>=1.2.0
#   Downloading pandas-1.3.4-cp38-cp38-win_amd64.whl (10.2 MB)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pyLDAvis) (1.21.2)
# Requirement already satisfied: joblib in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas>=1.2.0->pyLDAvis) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.16.0)
# Collecting Cython==0.29.23
#   Downloading Cython-0.29.23-cp38-cp38-win_amd64.whl (1.7 MB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp38-cp38-win_amd64.whl (14 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from scikit-learn->pyLDAvis) (3.0.0)
# Using legacy 'setup.py install' for future, since package 'wheel' is not installed.
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (PEP 517): started
#   Building wheel for pyLDAvis (PEP 517): finished with status 'done'
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136897 sha256=39647bdf5ab24147330a00ea3fa90fff6b2e5df439e3a4f566c1a1a2934ba74d
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\90\61\ec\9dbe9efc3acf9c4e37ba70fbbcc3f3a0ebd121060aa593181a
# Successfully built pyLDAvis
# Installing collected packages: smart-open, MarkupSafe, Cython, pandas, numexpr, jinja2, gensim, future, funcy, pyLDAvis
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#     Running setup.py install for future: started
#     Running setup.py install for future: finished with status 'done'
# Successfully installed Cython-0.29.23 MarkupSafe-2.0.1 funcy-1.16 future-0.18.2 gensim-4.1.2 jinja2-3.0.2 numexpr-2.7.3 pandas-1.3.4 pyLDAvis-3.3.1 smart-open-5.2.1
# ERROR: Could not find a version that satisfies the requirement pyLDAvis.gensim (from versions: none)
# ERROR: No matching distribution found for pyLDAvis.gensim
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Collecting bokeh
#   Downloading bokeh-2.4.1-py3-none-any.whl (18.5 MB)
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0-cp38-cp38-win_amd64.whl (155 kB)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from bokeh) (1.21.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from bokeh) (6.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from bokeh) (8.3.2)
# Collecting packaging>=16.8
#   Downloading packaging-21.2-py3-none-any.whl (40 kB)
# Collecting typing-extensions>=3.10.0
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from bokeh) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from Jinja2>=2.9->bokeh) (2.0.1)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from packaging>=16.8->bokeh) (2.4.7)
# Installing collected packages: typing-extensions, PyYAML, packaging, bokeh
# Successfully installed PyYAML-6.0 bokeh-2.4.1 packaging-21.2 typing-extensions-3.10.0.2
#   WARNING: The script bokeh.exe is installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: gensim in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from gensim) (1.21.2)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from gensim) (1.7.1)
# Requirement already satisfied: Cython==0.29.23 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from gensim) (0.29.23)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from gensim) (5.2.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Collecting spacy
#   Downloading spacy-3.1.4-cp38-cp38-win_amd64.whl (12.0 MB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp38-cp38-win_amd64.whl (113 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (21.2)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.6-cp38-cp38-win_amd64.whl (21 kB)
# Collecting tqdm<5.0.0,>=4.38.0
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-win_amd64.whl (2.0 MB)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (2.26.0)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.12-cp38-cp38-win_amd64.whl (1.0 MB)
#   WARNING: The script tqdm.exe is installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pathy.exe is installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: setuptools in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (57.4.0)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.5-cp38-cp38-win_amd64.whl (6.6 MB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (1.21.2)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: jinja2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (3.0.2)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.0-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp38-cp38-win_amd64.whl (452 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp38-cp38-win_amd64.whl (36 kB)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: colorama in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Collecting click<9.0.0,>=7.1.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: murmurhash, cymem, click, catalogue, wasabi, typer, srsly, pydantic, preshed, blis, tqdm, thinc, spacy-legacy, pathy, spacy
# Successfully installed blis-0.7.5 catalogue-2.0.6 click-8.0.3 cymem-2.0.6 murmurhash-1.0.6 pathy-0.6.1 preshed-3.0.6 pydantic-1.8.2 spacy-3.1.4 spacy-legacy-3.0.8 srsly-2.4.2 thinc-8.0.12 tqdm-4.62.3 typer-0.4.0 wasabi-0.8.2
# Collecting logging
#   Downloading logging-0.4.9.6.tar.gz (96 kB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Acer\\AppData\\Local\\Temp\\pip-install-s6usw7y5\\logging_368c860bfb5a4a238b5e0ed0fdc60454\\setup.py'"'"'; __file__='"'"'C:\\Users\\Acer\\AppData\\Local\\Temp\\pip-install-s6usw7y5\\logging_368c860bfb5a4a238b5e0ed0fdc60454\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Acer\AppData\Local\Temp\pip-pip-egg-info-cpgfzu_9'
#          cwd: C:\Users\Acer\AppData\Local\Temp\pip-install-s6usw7y5\logging_368c860bfb5a4a238b5e0ed0fdc60454\
#     Complete output (26 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\setuptools\__init__.py", line 18, in <module>
#         from setuptools.dist import Distribution
#       File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\setuptools\dist.py", line 32, in <module>
#         from setuptools.extern.more_itertools import unique_everseen
#       File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#       File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#       File "<frozen importlib._bootstrap>", line 657, in _load_unlocked
#       File "<frozen importlib._bootstrap>", line 556, in module_from_spec
#       File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\setuptools\extern\__init__.py", line 52, in create_module
#         return self.load_module(spec.name)
#       File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\setuptools\extern\__init__.py", line 37, in load_module
#         __import__(extant)
#       File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\setuptools\_vendor\more_itertools\__init__.py", line 1, in <module>
#         from .more import *  # noqa
#       File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\setuptools\_vendor\more_itertools\more.py", line 5, in <module>
#         from concurrent.futures import ThreadPoolExecutor
#       File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\__init__.py", line 8, in <module>
#         from concurrent.futures._base import (FIRST_COMPLETED,
#       File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py", line 7, in <module>
#         import logging
#       File "C:\Users\Acer\AppData\Local\Temp\pip-install-s6usw7y5\logging_368c860bfb5a4a238b5e0ed0fdc60454\logging\__init__.py", line 618
#         raise NotImplementedError, 'emit must be implemented '\
#                                  ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/93/4b/979db9e44be09f71e85c9c8cfc42f258adfb7d93ce01deed2788b2948919/logging-0.4.9.6.tar.gz#sha256=26f6b50773f085042d301085bd1bf5d9f3735704db9f37c1ce6d8b85c38f2417 (from https://pypi.org/simple/logging/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement logging (from versions: 0.4.9.6)
# ERROR: No matching distribution found for logging
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp38-cp38-win_amd64.whl (155 kB)
# Requirement already satisfied: pillow in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from wordcloud) (8.3.2)
# Requirement already satisfied: matplotlib in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from wordcloud) (1.21.2)
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1
# Collecting nltk
#   Downloading nltk-3.6.5-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: tqdm in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: joblib in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nltk) (8.0.3)
# Collecting regex>=2021.8.3
#   Downloading regex-2021.11.2-cp38-cp38-win_amd64.whl (273 kB)
# Requirement already satisfied: colorama in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from click->nltk) (0.4.4)
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.6.5 regex-2021.11.2
#   WARNING: The script nltk.exe is installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pip in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (21.2.4)
# Collecting pip
#   Downloading pip-21.3.1-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: setuptools in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (57.4.0)
#   WARNING: The script wheel.exe is installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pip.exe, pip3.8.exe and pip3.exe are installed in 'C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting setuptools
#   Using cached setuptools-58.4.0-py3-none-any.whl (946 kB)
# Collecting wheel
#   Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-21.3.1 setuptools-58.4.0 wheel-0.37.0
# Requirement already satisfied: spacy in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (3.1.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (21.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (4.62.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (2.26.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (0.7.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (8.0.12)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (1.21.2)
# Requirement already satisfied: jinja2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (3.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: setuptools in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy) (58.4.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: colorama in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jinja2->spacy) (2.0.1)
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from en-core-web-sm==3.1.0) (3.1.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.12)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.21.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.62.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.26.0)
# Requirement already satisfied: setuptools in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (58.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: colorama in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.1.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Requirement already satisfied: seaborn in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib>=2.2->seaborn) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: six in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Collecting translators
#   Downloading translators-4.9.5-py3-none-any.whl (20 kB)
# Collecting lxml>=4.5.0
#   Downloading lxml-4.6.4-cp38-cp38-win_amd64.whl (3.6 MB)
# Collecting pathos>=0.2.7
#   Downloading pathos-0.2.8-py2.py3-none-any.whl (81 kB)
# Collecting loguru>=0.4.1
#   Downloading loguru-0.5.3-py3-none-any.whl (57 kB)
# Collecting PyExecJS>=1.5.1
#   Downloading PyExecJS-1.5.1.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.25.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from translators) (2.26.0)
# Collecting win32-setctime>=1.0.0
#   Downloading win32_setctime-1.0.3-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from loguru>=0.4.1->translators) (0.4.4)
# Collecting dill>=0.3.4
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting ppft>=1.6.6.4
#   Downloading ppft-1.6.6.4-py3-none-any.whl (65 kB)
# Collecting multiprocess>=0.70.12
#   Downloading multiprocess-0.70.12.2-py38-none-any.whl (128 kB)
# Collecting pox>=0.3.0
#   Downloading pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from PyExecJS>=1.5.1->translators) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.25.1->translators) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.25.1->translators) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.25.1->translators) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.25.1->translators) (3.2)
# Building wheels for collected packages: PyExecJS
#   Building wheel for PyExecJS (setup.py): started
#   Building wheel for PyExecJS (setup.py): finished with status 'done'
#   Created wheel for PyExecJS: filename=PyExecJS-1.5.1-py3-none-any.whl size=14596 sha256=6c1b061371f207579dca9925b17d0c1a6023d72b9d7e07abdb0ecfb8e561a51d
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\db\3c\3d\7e9aca234caf6602ae4a4c7b367b3afc03519e791b998a94e4
# Successfully built PyExecJS
# Installing collected packages: dill, win32-setctime, ppft, pox, multiprocess, PyExecJS, pathos, lxml, loguru, translators
# Successfully installed PyExecJS-1.5.1 dill-0.3.4 loguru-0.5.3 lxml-4.6.4 multiprocess-0.70.12.2 pathos-0.2.8 pox-0.3.0 ppft-1.6.6.4 translators-4.9.5 win32-setctime-1.0.3
# Requirement already satisfied: pip in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (21.3.1)

# %%
import sys
import re
import numpy as np
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# NLTK Stop words
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 'co']) # After reviewering the LDA, return to add words that you want to eliminate

# Output:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(f'Total tweets: {len(df)}')
df_originals = df[~df['text'].str.contains("RT @")]
print(f'Original tweets: {len(df_originals)}')

# %%
def sent_to_words(sentences):
    for sent in sentences:
        sent = re.sub('\\S*@\\S*\\s?', '', sent)  # remove emails
        sent = re.sub('\\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)  

# Convert each tweet to a list of cleaned words and add to a master list
data = df_originals.text.values.tolist()
data_words = list(sent_to_words(data))
for tweet in data_words[:5]: # print the first :n tweet word lists
  print(tweet)

# %%
length = ''
for i in range(len(data_words)):
    for j in range(len(data_words[i])):
        length += data_words[i][j]
print(f'Corpus size: {str(len(length))}')

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=10) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=10)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
  # Remove stopwords, form bigrams and trigrams, and perform Lemmatization
  texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
  texts = [bigram_mod[doc] for doc in texts]
  texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
  
  texts_out = []
  nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])    # Load spacy, but we don't need the parser or NER (named entity extraction) modules
  
  for sent in texts:
    doc = nlp(" ".join(sent)) 
    texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
      
  # remove stopwords once more after lemmatization
  texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
  return texts_out

data_ready = process_words(data_words)  # processed Text Data!
for tweet in data_ready[:5]:
  print(tweet)

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)
for row in id2word.iteritems():
  print(row)

# %%
# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]
corpus

# %%
# Change the number of topics in the LDA here
topics = 4

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                            id2word=id2word,
                                            num_topics=topics,
                                            random_state=12345,
                                            chunksize=20,
                                            passes=10,
                                            per_word_topics=True)

ldatopics = lda_model.show_topics(formatted=False)
pprint(lda_model.print_topics())
